# %% [markdown]
# pandas package EDA Exploratory Data Analysis

# %%
# install
# !pip install pandas

# %% [markdown]
# pandas
#
# single dimensional series
#
# 2d data - data frame - rows and columns

# %%
import pandas as pd

# %%
df=pd.read_csv('diabetes_ds.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# DiabetesPedigreeFunction	- heredity factors percentages
#
# target variable - goal
#
# Outcome
#
# 1- presence of diabetes
#
# 0 - absence of diabetes

# %%
# copy
df_dia=df.copy()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_dia.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Read top 5 rows

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# read top 20 rows
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
# from end 5 rows
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# last 50 records
df.tail(50)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 718            1      108             60             46      178  35.5
# 719            5       97             76             27        0  35.6
# 720            4       83             86             19        0  29.3
# 721            1      114             66             36      200  38.1
# 722            1      149             68             29      127  29.3
# 723            5      117             86             30      105  39.1
# 724            1      111             94              0        0  32.8
# 725            4      112             78             40        0  39.4
# 726            1      116             78             29      180  36.1
# 727            0      141             84             26        0  32.4
# 728            2      175             88              0        0  22.9
# 729            2       92             52              0        0  30.1
# ...

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-14-2201091848.py in <cell line: 0>()
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.shape # number of rows and columns
# Out:
# (768, 9)

# %%
df.size # number of data
# Out:
# 6912

# %%
768*9
# Out:
# 6912

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# index first column - starts from 0 last -1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Preprocessing -

# %% [markdown]
# this shows there is no missing data, all columns are numeric, totally 9 columns

# %%
from google.colab import files
d=files.upload()
# Out:
#      <input type="file" id="files-8f438072-1b3d-432e-86eb-0e532a6662a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f438072-1b3d-432e-86eb-0e532a6662a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_tit=pd.read_csv('Titanic_ds.csv')
df_tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Survived
#
# 1- survival 0- died
#
# Pclass -passenger class 1,2,3
#
# SibSp	-siblings spouse
#
# Parch	-parents children
#
# Embarked- place - S- southampton C cherbourg Q queenstown

# %%
df_tit.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# NaN - Not an Number - data missing

# %% [markdown]
# checking missing data

# %%
df_tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# checking missing data
#
# isnull()
#
# isna()
#
# both are same

# %%
df_tit.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df_tit.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_tit.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df_tit.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# both isna and isnull are same

# %% [markdown]
# Data Imputation
#
# Handling missing data
#
# numeric - mean, median
#
# categorical data - mode - most repeated
#
# if more than 40 - 50% of data is missing, drop that columns
#
# dropna() removes rows with missing data
#
# fillna() fill null values
#
# isna() isnull() to check missing data

# %% [markdown]
# age, cabin, embarked

# %%
# age
print(df_tit['Age'].mean())
# Out:
# 29.69911764705882

# %%
df_tit['Age'].median()
# Out:
# 28.0

# %%
df_tit['Age']=df_tit['Age'].fillna(df_tit['Age'].mean())

# %%
df_tit.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_tit.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df_tit['Embarked']=df_tit['Embarked'].fillna(df_tit['Embarked'].mode()[0])

# %%
df_tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_tit.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df_tit=df_tit.drop(columns=['Cabin'],axis=1) # 1-column, 0 row

# %%
df_tit.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df_tit.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
# drop multiple columns
df_tit=df_tit.drop(columns=['PassengerId','Name','Ticket'],axis=1)

# %%
df_tit.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df=df.drop(columns=['SkinThickness'])

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df=df.drop(columns=['DiabetesPedigreeFunction'],axis=0)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'Age',
#        'Outcome'],
#       dtype='object')

# %% [markdown]
# Filter

# %%
# specific columns
df['BMI']
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
df_h=df[(df['BMI']>35)]
df_h
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome
# 4              0      137             40      168  43.1   33        1
# 7             10      115              0        0  35.3   29        0
# 10             4      110             92        0  37.6   30        0
# 11            10      168             74        0  38.0   34        1
# 16             0      118             84      230  45.8   31        1
# ..           ...      ...            ...      ...   ...  ...      ...
# 757            0      123             72        0  36.3   52        1
# 758            1      106             76        0  37.5   26        0
# 759            6      190             92        0  35.5   66        1
# 761            9      170             74        0  44.0   43        1
# 764            2      122             70        0  36.8   27        0
#
# [244 rows x 7 columns]

# %%
df_severe=df[(df['Age']>60) | (df['Glucose']>150)]
df_severe
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome
# 2              8      183             64        0  23.3   32        1
# 8              2      197             70      543  30.5   53        1
# 11            10      168             74        0  38.0   34        1
# 13             1      189             60      846  30.1   59        1
# 14             5      166             72      175  25.8   51        1
# ..           ...      ...            ...      ...   ...  ...      ...
# 753            0      181             88      510  43.3   26        1
# 754            8      154             78        0  32.4   45        1
# 759            6      190             92        0  35.5   66        1
# 761            9      170             74        0  44.0   43        1
# 763           10      101             76      180  32.9   63        0
#
# [160 rows x 7 columns]

# %% [markdown]
# indicator variable

# %%
import numpy as np
df['Result']=np.where((df['Age']>60) | (df['Glucose']>150),1,0)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'Age',
#        'Outcome', 'Result'],
#       dtype='object')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome  Result
# 0            6      148             72        0  33.6   50        1       0
# 1            1       85             66        0  26.6   31        0       0
# 2            8      183             64        0  23.3   32        1       1
# 3            1       89             66       94  28.1   21        0       0
# 4            0      137             40      168  43.1   33        1       0

# %%
df['Report']=np.where((df['Age']>60) | (df['Glucose']>150),'Positive','Negative')

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'Age',
#        'Outcome', 'Result', 'Report'],
#       dtype='object')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome  Result  \
# 0            6      148             72        0  33.6   50        1       0
# 1            1       85             66        0  26.6   31        0       0
# 2            8      183             64        0  23.3   32        1       1
# 3            1       89             66       94  28.1   21        0       0
# 4            0      137             40      168  43.1   33        1       0
#
#      Report
# 0  Negative
# 1  Negative
# 2  Positive
# 3  Negative
# 4  Negative

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome  Result  \
# 0              6      148             72        0  33.6   50        1       0
# 1              1       85             66        0  26.6   31        0       0
# 2              8      183             64        0  23.3   32        1       1
# 3              1       89             66       94  28.1   21        0       0
# 4              0      137             40      168  43.1   33        1       0
# ..           ...      ...            ...      ...   ...  ...      ...     ...
# 763           10      101             76      180  32.9   63        0       1
# 764            2      122             70        0  36.8   27        0       0
# 765            5      121             72      112  26.2   30        0       0
# 766            1      126             60        0  30.1   47        1       0
# 767            1       93             70        0  30.4   23        0       0
#
#        Report
# 0    Negative
# ...

# %% [markdown]
# Extract specific rows and columns
#
# slicing
#
# loc - locates row using name
#
# iloc - integer locates - numbers

# %%
# extract rows
df.iloc[10:20] #19
# Out:
#     Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome  Result  \
# 10            4      110             92        0  37.6   30        0       0
# 11           10      168             74        0  38.0   34        1       1
# 12           10      139             80        0  27.1   57        0       0
# 13            1      189             60      846  30.1   59        1       1
# 14            5      166             72      175  25.8   51        1       1
# 15            7      100              0        0  30.0   32        1       0
# 16            0      118             84      230  45.8   31        1       0
# 17            7      107             74        0  29.6   31        1       0
# 18            1      103             30       83  43.3   33        0       0
# 19            1      115             70       96  34.6   32        1       0
#
#       Report
# 10  Negative
# 11  Positive
# 12  Negative
# 13  Positive
# 14  Positive
# 15  Negative
# 16  Negative
# ...

# %%
df.iloc[100:140]
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome  Result  \
# 100            1      163             72        0  39.0   33        1       1
# 101            1      151             60        0  26.1   22        0       1
# 102            0      125             96        0  22.5   21        0       0
# 103            1       81             72       40  26.6   24        0       0
# 104            2       85             65        0  39.6   27        0       0
# 105            1      126             56      152  28.7   21        0       0
# 106            1       96            122        0  22.4   27        0       0
# 107            4      144             58      140  29.5   37        0       0
# 108            3       83             58       18  34.3   25        0       0
# 109            0       95             85       36  37.4   24        1       0
# 110            3      171             72      135  33.3   24        1       1
# ...

# %%
# rows and columns
df.iloc[10:15][['Glucose','BloodPressure']]
# Out:
#     Glucose  BloodPressure
# 10      110             92
# 11      168             74
# 12      139             80
# 13      189             60
# 14      166             72

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'Age',
#        'Outcome', 'Result', 'Report'],
#       dtype='object')

# %%
df.iloc[:,[2]] # 3rd column
# Out:
#      BloodPressure
# 0               72
# 1               66
# 2               64
# 3               66
# 4               40
# ..             ...
# 763             76
# 764             70
# 765             72
# 766             60
# 767             70
#
# [768 rows x 1 columns]

# %%
df_vital=df.iloc[:,2:6] # all rows , cols 2,3,4,5
df_vital
# Out:
#      BloodPressure  Insulin   BMI  Age
# 0               72        0  33.6   50
# 1               66        0  26.6   31
# 2               64        0  23.3   32
# 3               66       94  28.1   21
# 4               40      168  43.1   33
# ..             ...      ...   ...  ...
# 763             76      180  32.9   63
# 764             70        0  36.8   27
# 765             72      112  26.2   30
# 766             60        0  30.1   47
# 767             70        0  30.4   23
#
# [768 rows x 4 columns]

# %% [markdown]
# Statistical Analysis
#
# mean,median, min, max,count - numerical columns

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure     Insulin         BMI  \
# count   768.000000  768.000000     768.000000  768.000000  768.000000
# mean      3.845052  120.894531      69.105469   79.799479   31.992578
# std       3.369578   31.972618      19.355807  115.244002    7.884160
# min       0.000000    0.000000       0.000000    0.000000    0.000000
# 25%       1.000000   99.000000      62.000000    0.000000   27.300000
# 50%       3.000000  117.000000      72.000000   30.500000   32.000000
# 75%       6.000000  140.250000      80.000000  127.250000   36.600000
# max      17.000000  199.000000     122.000000  846.000000   67.100000
#
#               Age     Outcome      Result
# count  768.000000  768.000000  768.000000
# mean    33.240885    0.348958    0.208333
# std     11.760232    0.476951    0.406381
# min     21.000000    0.000000    0.000000
# 25%     24.000000    0.000000    0.000000
# 50%     29.000000    0.000000    0.000000
# ...

# %%
df.describe().T
# Out:
#                count        mean         std   min   25%    50%     75%    max
# Pregnancies    768.0    3.845052    3.369578   0.0   1.0    3.0    6.00   17.0
# Glucose        768.0  120.894531   31.972618   0.0  99.0  117.0  140.25  199.0
# BloodPressure  768.0   69.105469   19.355807   0.0  62.0   72.0   80.00  122.0
# Insulin        768.0   79.799479  115.244002   0.0   0.0   30.5  127.25  846.0
# BMI            768.0   31.992578    7.884160   0.0  27.3   32.0   36.60   67.1
# Age            768.0   33.240885   11.760232  21.0  24.0   29.0   41.00   81.0
# Outcome        768.0    0.348958    0.476951   0.0   0.0    0.0    1.00    1.0
# Result         768.0    0.208333    0.406381   0.0   0.0    0.0    0.00    1.0

# %% [markdown]
# Correlation
#
# finds relationship among variables

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome  Result  \
# 0            6      148             72        0  33.6   50        1       0
# 1            1       85             66        0  26.6   31        0       0
# 2            8      183             64        0  23.3   32        1       1
# 3            1       89             66       94  28.1   21        0       0
# 4            0      137             40      168  43.1   33        1       0
#
#      Report
# 0  Negative
# 1  Negative
# 2  Positive
# 3  Negative
# 4  Negative

# %%
df_tit
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df_tit.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-73-3339295567.py in <cell line: 0>()
# ----> 1 df_tit.corr()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
import seaborn as sns
sns.heatmap(data=df_tit.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-74-3968301493.py in <cell line: 0>()
#       1 import seaborn as sns
# ----> 2 sns.heatmap(data=df_tit.corr())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
# ...

# %%
df.drop(columns=['Report'],axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome  Result
# 0              6      148             72        0  33.6   50        1       0
# 1              1       85             66        0  26.6   31        0       0
# 2              8      183             64        0  23.3   32        1       1
# 3              1       89             66       94  28.1   21        0       0
# 4              0      137             40      168  43.1   33        1       0
# ..           ...      ...            ...      ...   ...  ...      ...     ...
# 763           10      101             76      180  32.9   63        0       1
# 764            2      122             70        0  36.8   27        0       0
# 765            5      121             72      112  26.2   30        0       0
# 766            1      126             60        0  30.1   47        1       0
# 767            1       93             70        0  30.4   23        0       0
#
# [768 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'Insulin', 'BMI', 'Age',
#        'Outcome', 'Result', 'Report'],
#       dtype='object')

# %%
df_dia.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.heatmap(data=df_dia.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(data=df_dia.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(data=df_dia.corr(),annot=True,fmt='0.1f')
# Out:
# <Axes: >

# %%
sns.heatmap(data=df_dia.corr(),annot=True,fmt='0.2f')
# Out:
# <Axes: >

# %%
sns.heatmap(data=df_dia.corr(),annot=True,fmt='0.2f',cmap='viridis',linewidths=4,linecolor='yellow')
# Out:
# <Axes: >

# %% [markdown]
# Label Encoding
#
# convert strings( objects ) to numbers

# %%
df.dtypes
# Out:
# Pregnancies        int64
# Glucose            int64
# BloodPressure      int64
# Insulin            int64
# BMI              float64
# Age                int64
# Outcome            int64
# Result             int64
# Report            object
# dtype: object

# %%
df_tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %% [markdown]
# Label encoder
#
# getdummies
#
# map - uses dictionary

# %%
df_tit.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df_tit['Sex']=df_tit['Sex'].map({'male':1,'female':0}) # only once

# %%
df_tit.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3  1.0  22.0      1      0   7.2500        S
# 1         1       1  NaN  38.0      1      0  71.2833        C
# 2         1       3  NaN  26.0      0      0   7.9250        S
# 3         1       1  NaN  35.0      1      0  53.1000        S
# 4         0       3  1.0  35.0      0      0   8.0500        S

# %%
pd.get_dummies(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  Insulin   BMI  Age  Outcome  Result  \
# 0              6      148             72        0  33.6   50        1       0
# 1              1       85             66        0  26.6   31        0       0
# 2              8      183             64        0  23.3   32        1       1
# 3              1       89             66       94  28.1   21        0       0
# 4              0      137             40      168  43.1   33        1       0
# ..           ...      ...            ...      ...   ...  ...      ...     ...
# 763           10      101             76      180  32.9   63        0       1
# 764            2      122             70        0  36.8   27        0       0
# 765            5      121             72      112  26.2   30        0       0
# 766            1      126             60        0  30.1   47        1       0
# 767            1       93             70        0  30.4   23        0       0
#
# ...

# %%
df_tit
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3  1.0  22.000000      1      0   7.2500        S
# 1           1       1  NaN  38.000000      1      0  71.2833        C
# 2           1       3  NaN  26.000000      0      0   7.9250        S
# 3           1       1  NaN  35.000000      1      0  53.1000        S
# 4           0       3  1.0  35.000000      0      0   8.0500        S
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2  1.0  27.000000      0      0  13.0000        S
# 887         1       1  NaN  19.000000      0      0  30.0000        S
# 888         0       3  NaN  29.699118      1      2  23.4500        S
# 889         1       1  1.0  26.000000      0      0  30.0000        C
# 890         0       3  1.0  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df_tit['Embarked']=le.fit_transform(df_tit['Embarked'])

# %%
df_tit.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3  1.0  22.0      1      0   7.2500         2
# 1         1       1  NaN  38.0      1      0  71.2833         0
# 2         1       3  NaN  26.0      0      0   7.9250         2
# 3         1       1  NaN  35.0      1      0  53.1000         2
# 4         0       3  1.0  35.0      0      0   8.0500         2
