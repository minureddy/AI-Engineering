# %%
# Import numpy and pandas package
import pandas as pd
import numpy as np
# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("house_price_prediction.xlsx")

# %%
df.head(5)
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
# 1            4272             3              3        2016  4.753014
# 2            3592             1              2        2016  3.634823
# 3             966             1              2        1977  2.730667
# 4            4926             2              1        1993  4.699073
#
#    Garage_Size  Neighborhood_Quality   House_Price
# 0            0                     5  2.623829e+05
# 1            1                     6  9.852609e+05
# 2            0                     9  7.779774e+05
# 3            1                     8  2.296989e+05
# 4            0                     8  1.041741e+06

# %%
df.describe()
# Out:
#        Square_Footage  Num_Bedrooms  Num_Bathrooms   Year_Built     Lot_Size  \
# count     1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean      2815.422000      2.990000       1.973000  1986.550000     2.778087
# std       1255.514921      1.427564       0.820332    20.632916     1.297903
# min        503.000000      1.000000       1.000000  1950.000000     0.506058
# 25%       1749.500000      2.000000       1.000000  1969.000000     1.665946
# 50%       2862.500000      3.000000       2.000000  1986.000000     2.809740
# 75%       3849.500000      4.000000       3.000000  2004.250000     3.923317
# max       4999.000000      5.000000       3.000000  2022.000000     4.989303
#
#        Garage_Size  Neighborhood_Quality   House_Price
# count  1000.000000           1000.000000  1.000000e+03
# mean      1.022000              5.615000  6.188610e+05
# std       0.814973              2.887059  2.535681e+05
# ...

# %%
df.dtypes
# Out:
# Square_Footage            int64
# Num_Bedrooms              int64
# Num_Bathrooms             int64
# Year_Built                int64
# Lot_Size                float64
# Garage_Size               int64
# Neighborhood_Quality      int64
# House_Price             float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Square_Footage          0
# Num_Bedrooms            0
# Num_Bathrooms           0
# Year_Built              0
# Lot_Size                0
# Garage_Size             0
# Neighborhood_Quality    0
# House_Price             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Square_Footage', 'Num_Bedrooms', 'Num_Bathrooms', 'Year_Built',
#        'Lot_Size', 'Garage_Size', 'Neighborhood_Quality', 'House_Price'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 8)

# %%
# Outlier Analysis
fig, axs = plt.subplots(3,2, figsize = (10,17))
plt1 = sns.boxplot(df['House_Price'], ax = axs[0,0])
plt2 = sns.boxplot(df['Year_Built'], ax = axs[0,1])
plt3 = sns.boxplot(df['Num_Bathrooms'], ax = axs[1,0])
plt1 = sns.boxplot(df['Num_Bedrooms'], ax = axs[1,1])
plt2 = sns.boxplot(df['Square_Footage'], ax = axs[2,1])
plt3 = sns.boxplot(df['Lot_Size'], ax = axs[2,0])

plt.tight_layout()

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr()
# Out:
#                       Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  \
# Square_Footage              1.000000     -0.043564      -0.031584   -0.022392
# Num_Bedrooms               -0.043564      1.000000       0.022848   -0.015820
# Num_Bathrooms              -0.031584      0.022848       1.000000   -0.021063
# Year_Built                 -0.022392     -0.015820      -0.021063    1.000000
# Lot_Size                    0.089479     -0.009355       0.034923   -0.061050
# Garage_Size                 0.030593      0.113761       0.024846   -0.025485
# Neighborhood_Quality       -0.008357     -0.049024       0.017585   -0.009549
# House_Price                 0.991261      0.014633      -0.001862    0.051967
#
#                       Lot_Size  Garage_Size  Neighborhood_Quality  House_Price
# Square_Footage        0.089479     0.030593             -0.008357     0.991261
# Num_Bedrooms         -0.009355     0.113761             -0.049024     0.014633
# ...

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(df.corr(), annot = True, cmap="YlOrRd")
plt.show()

# %%
plt.scatter(df['House_Price'],df['Neighborhood_Quality'],color='orange')

# %%
plt.scatter(df['House_Price'],df['Square_Footage'],color='yellow')

# %%
plt.scatter(df['House_Price'],df['Lot_Size'],color='red')

# %%
x= df.iloc[:,:-1]
x.columns
# Out:
# Index(['Square_Footage', 'Num_Bedrooms', 'Num_Bathrooms', 'Year_Built',
#        'Lot_Size', 'Garage_Size', 'Neighborhood_Quality'],
#       dtype='object')

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      2.623829e+05
# 1      9.852609e+05
# 2      7.779774e+05
# 3      2.296989e+05
# 4      1.041741e+06
#            ...
# 995    7.014940e+05
# 996    6.837232e+05
# 997    5.720240e+05
# 998    9.648653e+05
# 999    7.425993e+05
# Name: House_Price, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.9,random_state=42)

# %%
xtrain.shape
# Out:
# (900, 7)

# %%
xtest.shape
# Out:
# (100, 7)

# %%
from sklearn.preprocessing import StandardScaler
# standardization
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
xtrain
# Out:
# array([[ 1.12719601,  0.02023041,  1.26814648, ..., -0.66297112,
#         -0.02450225,  0.83359124],
#        [ 0.94438719,  0.72051371,  0.04616379, ..., -1.29939292,
#          1.20061021, -0.54741587],
#        [-1.62691072,  1.42079701,  1.26814648, ...,  0.82204527,
#          1.20061021, -0.89266765],
#        ...,
#        [-1.06890475,  1.42079701, -1.1758189 , ..., -1.17967051,
#         -0.02450225,  0.14308768],
#        [-0.76475557,  0.72051371,  0.04616379, ...,  1.23450683,
#         -1.24961471,  0.48833946],
#        [-1.16549805,  0.72051371, -1.1758189 , ...,  1.27696772,
#         -0.02450225, -1.58317121]])

# %%
xtest
# Out:
# array([[ 0.94917694,  0.02023041, -1.1758189 ,  1.42268474, -0.51815687,
#         -0.02450225, -0.2021641 ],
#        [-0.40951571,  0.02023041, -1.1758189 ,  0.06595227, -1.08406583,
#         -0.02450225, -0.54741587],
#        [ 1.50478804, -1.38033619,  1.26814648, -1.19387074, -0.75518979,
#         -0.02450225,  0.83359124],
#        [ 1.6836054 , -0.68005289, -1.1758189 , -0.70932342,  1.33190611,
#         -0.02450225, -1.23791943],
#        [ 0.65700214, -1.38033619, -1.1758189 ,  0.35668066,  0.94456233,
#         -1.24961471,  1.17884301],
#        [ 0.60910463, -0.68005289,  0.04616379, -1.09696127, -0.15277806,
#         -1.24961471,  1.52409479],
#        [ 1.44890761,  0.72051371,  1.26814648,  0.64740905, -0.99024096,
#         -0.02450225, -0.89266765],
#        [ 1.0409805 ,  1.42079701,  0.04616379,  0.2597712 , -1.35088634,
#          1.20061021, -1.58317121],
#        [ 0.76477153, -0.68005289, -1.1758189 ,  0.114407  ,  0.30994794,
# ...

# %%
sns.boxplot(data=x)
# Out:
# <Axes: >

# %%
sns.boxplot(data=xtrain)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

# %%
mullinear=LinearRegression()
mullinear.fit(xtrain,ytrain)
ypred=mullinear.predict(xtest)

# %%
ypred
# Out:
# array([ 868458.16599603,  490131.93047753,  945619.57716325,
#        1033595.19173796,  776498.65011036,  732317.28367702,
#         995118.72657952,  885205.92010789,  796520.74544899,
#         931615.71950273,  759456.375469  ,  645173.03437497,
#         217526.20215004, 1047672.17636852,  536587.56430726,
#         187787.28760339,  456654.08526054,  357587.21783345,
#         743077.16830641,  362607.64572159,  774838.01218696,
#         478204.99719328,  680719.94439894,  889687.77275132,
#         447069.81786484,  397033.51466532,  454599.43973151,
#         443019.32908963,  187303.53452397,  491622.09184068,
#         279787.38690572,  896268.31260911,  783408.57258653,
#         352239.40094768,  479392.50404377,  766624.12669389,
#         474563.36041892,  572499.70759701,  303484.16983207,
#         154575.93870894,  304350.32591323,  299653.95731224,
#         508612.44176335,  309717.39606133, 1082294.02062788,
# ...

# %%
plt.scatter(ytest,ypred)

# %%
# Evaluation metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error,root_mean_squared_error,r2_score

# %%
r2_score(ytest,ypred)
# Out:
# 0.9983996902956828

# %%
# Evaluation metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error,root_mean_squared_error,r2_score

# %%
root_mean_squared_error(ytest,ypred)
# Out:
# 10367.89959577153

# %%
mean_squared_error(ytest,ypred)
# Out:
# 107493342.02799948

# %%
mean_absolute_error(ytest,ypred)
# Out:
# 8185.595411861682

# %%
root_mean_squared_error(ytest,ypred)
# Out:
# 10367.89959577153

# %%
# Residual Plot- to check linerarity and homoscediacity
residuals = ytest - ypred
plt.scatter(ypred, residuals, alpha=0.3)
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.axhline(y=0, color='red', linestyle='--')
plt.show()

# Predicted vs Actual Plot
plt.scatter(ytest, ypred, alpha=0.3)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs Actual Values')
plt.plot([ytest.min(), ytest.max()], [ytest.min(), ytest.max()], 'r--', lw=1)
plt.show()

# %%
print("Min:", y.min())
print("Max:", y.max())
print("Mean:", y.mean())
print("Std Deviation:", y.std())
# Out:
# Min: 111626.853423615
# Max: 1108236.83629136
# Mean: 618861.0186467677
# Std Deviation: 253568.05837542028

# %%
residuals = ytest - ypred

# %%
import matplotlib.pyplot as plt

plt.scatter(ypred, residuals)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Predicted')
plt.show()

# %%
# Q-Q Plot for Normality of Residuals

import scipy.stats as stats

# Histogram
sns.histplot(residuals, kde=True)
plt.title("Histogram of Residuals")
plt.show()

# Q-Q Plot
stats.probplot(residuals,plot=plt,dist='norm')

plt.title("Q-Q Plot")
plt.show()

# %%
from statsmodels.stats.stattools import durbin_watson

dw_stat = durbin_watson(residuals)
print(f"Durbin-Watson Statistic: {dw_stat}")
# Out:
# Durbin-Watson Statistic: 1.6229234030712194

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

vif_df = pd.DataFrame()
vif_df["feature"] = x.columns
vif_df["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]

print(vif_df)
# Out:
#                 feature        VIF
# 0        Square_Footage   6.101523
# 1          Num_Bedrooms   5.483174
# 2         Num_Bathrooms   6.806133
# 3            Year_Built  24.704359
# 4              Lot_Size   5.633428
# 5           Garage_Size   2.611489
# 6  Neighborhood_Quality   4.803468

# %%
# Assume you have X_train, X_test, y_train, y_test already prepared
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
# Ridge Regression
ridge = Ridge(alpha=1.0)  # alpha controls regularization strength
ridge.fit(xtrain, ytrain)
y_pred_ridge = ridge.predict(xtest)

print("Ridge RMSE:", np.sqrt(mean_squared_error(ytest, y_pred_ridge)))
print("Ridge R2:", r2_score(ytest, y_pred_ridge))

# Lasso Regression
lasso = Lasso(alpha=0.1)  # tune alpha via cross-validation
lasso.fit(xtrain, ytrain)
y_pred_lasso = lasso.predict(xtest)

print("Lasso RMSE:", np.sqrt(mean_squared_error(ytest, y_pred_lasso)))
print("Lasso R2:", r2_score(ytest, y_pred_lasso))
# Out:
# Ridge RMSE: 10441.348220119993
# Ridge R2: 0.9983769360458798
# Lasso RMSE: 10367.921108256294
# Lasso R2: 0.9983996836546706
